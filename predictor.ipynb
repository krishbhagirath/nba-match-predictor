# %%
import pandas as pd

# %%
data = pd.read_csv("data/nba_games_raw.csv", index_col=0)

# %%
data
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  39.0   81.0  0.481   6.0  20.0  0.300  14.0  18.0  ...
# 1      240.0  240.0  36.0  100.0  0.360   7.0  31.0  0.226  16.0  19.0  ...
# 2      240.0  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0  23.0  ...
# 3      240.0  240.0  41.0   89.0  0.461   8.0  21.0  0.381  17.0  19.0  ...
# 4      240.0  240.0  27.0   86.0  0.314   6.0  26.0  0.231  15.0  20.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 17767  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0  36.0  ...
# 17768  240.0  240.0  37.0   74.0  0.500  13.0  25.0  0.520  26.0  37.0  ...
# 17769  240.0  240.0  42.0   89.0  0.472  14.0  33.0  0.424  10.0  20.0  ...
# 17770  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 17771  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              22.8          29.0         178.0         111.0       DAL
# 1              50.0          32.6         152.0         111.0       ATL
# 2              20.0          30.9         148.0         116.0       SAS
# 3              28.6          30.9         138.0         118.0       MIN
# 4              16.8          30.9         157.0          90.0       MEM
# ...             ...           ...           ...           ...       ...
# 17767          34.2          33.7         160.0         118.0       OKC
# 17768          25.0          30.0         139.0         129.0       ORL
# 17769          25.6          29.9         175.0         126.0       LAC
# 17770          27.7          27.1         150.0         126.0       MIA
# 17771          51.5          36.2         141.0         114.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0             95         1    2016  2015-12-09   True
# 1             98         0    2016  2015-12-09  False
# 2            107         1    2018  2017-10-18  False
# 3             99         0    2018  2017-10-18   True
# 4             92         1    2021  2021-04-30  False
# ...          ...       ...     ...         ...    ...
# 17767         92         0    2019  2018-10-19   True
# 17768        108         1    2017  2016-12-14   True
# 17769        113         0    2017  2016-12-14  False
# 17770        106         1    2020  2020-09-19   True
# 17771        117         0    2020  2020-09-19  False
#
# [17772 rows x 150 columns]

# %%
data = data.sort_values("date")

# %%
data = data.reset_index(drop=True) # Reset index after sorting

# %%
data
# Out:
#           mp   mp.1    fg   fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  ...
# 1      240.0  240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  ...
# 2      240.0  240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  ...
# 3      240.0  240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  ...
# 4      240.0  240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  ...
# ...      ...    ...   ...   ...    ...   ...   ...    ...   ...   ...  ...
# 17767  240.0  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  ...
# 17768  240.0  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  ...
# 17769  240.0  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  ...
# 17770  240.0  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  ...
# 17771  240.0  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              69.4          43.7         206.0         104.0       GSW
# 1              53.2          34.6         162.0         104.0       CHI
# 2              30.4          29.0         138.0         105.0       CLE
# 3              37.5          38.9         201.0         120.0       NOP
# 4              33.3          23.6         132.0         104.0       DET
# ...             ...           ...           ...           ...       ...
# 17767          42.9          36.3         133.0         112.0       GSW
# 17768          45.0          94.4         300.0         112.0       BOS
# 17769          33.3          36.2         222.0         107.0       GSW
# 17770          33.3          31.5         186.0         111.0       GSW
# 17771         100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0            111         1    2016  2015-10-27  False
# 1             97         1    2016  2015-10-27  False
# 2             95         0    2016  2015-10-27   True
# 3             95         0    2016  2015-10-27   True
# 4            106         0    2016  2015-10-27  False
# ...          ...       ...     ...         ...    ...
# 17767        107         0    2022  2022-06-10  False
# 17768         94         0    2022  2022-06-13   True
# 17769        104         1    2022  2022-06-13  False
# 17770        103         0    2022  2022-06-16  False
# 17771         90         1    2022  2022-06-16   True
#
# [17772 rows x 150 columns]

# %%
del data["mp.1"]
del data["mp_opp.1"]
del data["index_opp"]

# %%
data
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0              69.4          43.7         206.0         104.0       GSW
# 1              53.2          34.6         162.0         104.0       CHI
# 2              30.4          29.0         138.0         105.0       CLE
# 3              37.5          38.9         201.0         120.0       NOP
# 4              33.3          23.6         132.0         104.0       DET
# ...             ...           ...           ...           ...       ...
# 17767          42.9          36.3         133.0         112.0       GSW
# 17768          45.0          94.4         300.0         112.0       BOS
# 17769          33.3          36.2         222.0         107.0       GSW
# 17770          33.3          31.5         186.0         111.0       GSW
# 17771         100.0          42.6         141.0         126.0       BOS
#
#        total_opp  home_opp  season        date    won
# 0            111         1    2016  2015-10-27  False
# 1             97         1    2016  2015-10-27  False
# 2             95         0    2016  2015-10-27   True
# 3             95         0    2016  2015-10-27   True
# 4            106         0    2016  2015-10-27  False
# ...          ...       ...     ...         ...    ...
# 17767        107         0    2022  2022-06-10  False
# 17768         94         0    2022  2022-06-13   True
# 17769        104         1    2022  2022-06-13  False
# 17770        103         0    2022  2022-06-16  False
# 17771         90         1    2022  2022-06-16   True
#
# [17772 rows x 147 columns]

# %%
def add_target(team):
    team["target"] = team["won"].shift(-1)
    return team

data = data.groupby("team", group_keys=False).apply(add_target) #split up data frames by team, apply function to each group

# %%
data[data["team"] == "TOR"]
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 7      240.0  36.0  80.0  0.450   7.0  18.0  0.389  27.0  39.0  0.692  ...
# 41     240.0  36.0  82.0  0.439  11.0  26.0  0.423  30.0  35.0  0.857  ...
# 84     240.0  41.0  90.0  0.456  11.0  25.0  0.440  13.0  20.0  0.650  ...
# 104    240.0  37.0  82.0  0.451   5.0  17.0  0.294  23.0  26.0  0.885  ...
# 123    240.0  33.0  79.0  0.418   5.0  14.0  0.357  32.0  39.0  0.821  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17615  240.0  38.0  89.0  0.427  11.0  32.0  0.344  10.0  12.0  0.833  ...
# 17631  265.0  38.0  86.0  0.442  13.0  35.0  0.371  12.0  18.0  0.667  ...
# 17651  240.0  37.0  88.0  0.420   8.0  34.0  0.235  28.0  35.0  0.800  ...
# 17661  240.0  42.0  82.0  0.512   8.0  31.0  0.258  11.0  13.0  0.846  ...
# 17677  240.0  35.0  89.0  0.393   7.0  35.0  0.200  20.0  25.0  0.800  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 7              31.1         127.0         110.0       IND         99
# 41             32.7         120.0         116.0       BOS        103
# 84             53.8         150.0         130.0       MIL         87
# 104           100.0         136.0         114.0       DAL         91
# 123            39.0         139.0         119.0       OKC         98
# ...             ...           ...           ...       ...        ...
# 17615          35.1         183.0         123.0       PHI        112
# 17631          34.1         246.0         115.0       PHI        104
# 17651          32.7         300.0         121.0       PHI        102
# 17661          46.2         300.0         117.0       PHI         88
# 17677          42.4         234.0         117.0       PHI        132
#
#        home_opp  season        date    won  target
# 7             0    2016  2015-10-28   True    True
# 41            1    2016  2015-10-30   True    True
# 84            0    2016  2015-11-01   True    True
# 104           1    2016  2015-11-03   True    True
# 123           1    2016  2015-11-04   True   False
# ...         ...     ...         ...    ...     ...
# 17615         1    2022  2022-04-18  False   False
# 17631         0    2022  2022-04-20  False    True
# 17651         0    2022  2022-04-23   True    True
# 17661         1    2022  2022-04-25   True   False
# 17677         0    2022  2022-04-28  False     NaN
#
# [635 rows x 148 columns]

# %%
data["target"][pd.isnull(data["target"])] = 2 # Set target to 0 for last game of each team
# Out:
# <ipython-input-14-4decd6877643>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["target"][pd.isnull(data["target"])] = 2 # Set target to 0 for last game of each team

# %%
data["target"] = data["target"].astype(int, errors="ignore") # Convert target to integer type

# %%
data
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              29.0         138.0         105.0       CLE         95
# 3              38.9         201.0         120.0       NOP         95
# 4              23.6         132.0         104.0       DET        106
# ...             ...           ...           ...       ...        ...
# 17767          36.3         133.0         112.0       GSW        107
# 17768          94.4         300.0         112.0       BOS         94
# 17769          36.2         222.0         107.0       GSW        104
# 17770          31.5         186.0         111.0       GSW        103
# 17771          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 148 columns]

# %%
data["won"].value_counts()
# Out:
# False    8886
# True     8886
# Name: won, dtype: int64

# %%
data["target"].value_counts()
# Out:
# 1    8872
# 0    8870
# 2      30
# Name: target, dtype: int64

# %%
nulls = pd.isnull(data) # Check for null values in the DataFrame

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]
nulls
# Out:
# +/-             17772
# mp_max          17772
# mp_max.1        17772
# +/-_opp         17772
# mp_max_opp      17772
# mp_max_opp.1    17772
# dtype: int64

# %%
valid_columns = data.columns[~data.columns.isin(nulls.index)] # negates the columns in nulls, stores valid columns

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
data = data[valid_columns].copy() # copy now to avoid SettingWithCopyWarning

# %%
data # DATA CLEANING COMPLETE
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              43.7         206.0         104.0       GSW        111
# 1              34.6         162.0         104.0       CHI         97
# 2              29.0         138.0         105.0       CLE         95
# 3              38.9         201.0         120.0       NOP         95
# 4              23.6         132.0         104.0       DET        106
# ...             ...           ...           ...       ...        ...
# 17767          36.3         133.0         112.0       GSW        107
# 17768          94.4         300.0         112.0       BOS         94
# 17769          36.2         222.0         107.0       GSW        104
# 17770          31.5         186.0         111.0       GSW        103
# 17771          42.6         141.0         126.0       BOS         90
#
#        home_opp  season        date    won  target
# 0             1    2016  2015-10-27  False       0
# 1             1    2016  2015-10-27  False       1
# 2             0    2016  2015-10-27   True       1
# 3             0    2016  2015-10-27   True       1
# 4             0    2016  2015-10-27  False       1
# ...         ...     ...         ...    ...     ...
# 17767         0    2022  2022-06-10  False       0
# 17768         0    2022  2022-06-13   True       1
# 17769         1    2022  2022-06-13  False       0
# 17770         0    2022  2022-06-16  False       2
# 17771         1    2022  2022-06-16   True       2
#
# [17772 rows x 142 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit     # import for feature selection (only want to train with certain data)
# ensures we are only using past data to predict future outcomes (not vice versa!)

from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=0.1) # rr -> Ridge Regression (allows for classification) -> the MODEL itself
split = TimeSeriesSplit(n_splits=3) # cross-validation strategy, 3 splits for time series cross-validation

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split) # feature selection strategy: will train the model (rr) using different sets of features

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"] # these columns are not to be used in the model
# to optimize Ridge Regression performance, we scale the columns to values between 0 and 1
# removed_columns includes columns that are NOT to be scaled

# %%
selected_columns = data.columns[~data.columns.isin(removed_columns)] # negate columns in removed_columns

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() # scaler to scale the data between 0 and 1
data[selected_columns] = scaler.fit_transform(data[selected_columns]) # scale the data using SciKit-learn's MinMaxScaler

# %%
data # DATA SCALING COMPLETE
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# 1      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 2      0.348837  0.349206  0.645274  ...      0.088575      0.232227
# 3      0.441860  0.333333  0.893816  ...      0.215661      0.530806
# 4      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17768  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17769  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17770  0.232558  0.174603  0.903151  ...      0.120668      0.459716
# 17771  0.162791  0.111111  1.000000  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 2          0.329412       CLE   0.298077       0.0    2016  2015-10-27   True
# 3          0.505882       NOP   0.298077       0.0    2016  2015-10-27   True
# 4          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# ...             ...       ...        ...       ...     ...         ...    ...
# 17767      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17768      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17769      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17770      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
# 17771      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17767       0
# 17768       1
# 17769       0
# 17770       2
# 17771       2
#
# [17772 rows x 142 columns]

# %%
import joblib

# Save cleaned, scaled data
data.to_csv('data/nba_games_scaled.csv', index=False)

# %%
sfs.fit(data[selected_columns], data["target"]) # fit the feature selector to the data
# uses rr model to try different combinations of features to find the best set of features that predict TARGET (the outcome of the NEXT game)
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=0.1),
#                           n_features_to_select=30)

# %%
# sfs = joblib.load('models/ridge_regression/feature_selector_unoptimized.pkl') # load the feature selector from file for future use
# rr  = joblib.load('models/ridge_regression/model_unoptimized.pkl') # load the model from file for future use

# %%
predictors = list(selected_columns[sfs.get_support()]) # get the selected features from the feature selector

# %%
predictors
# Out:
# ['mp',
#  'fg%',
#  'orb%',
#  'trb%',
#  'usg%',
#  'fg%_max',
#  'ft_max',
#  '+/-_max',
#  'ts%_max',
#  'drb%_max',
#  'tov%_max',
#  'usg%_max',
#  'mp_opp',
#  'fg_opp',
#  '3p_opp',
#  'blk_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  'fg_max_opp',
#  'fga_max_opp',
#  '3p%_max_opp',
#  'ft%_max_opp',
#  'stl_max_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'pts_max_opp',
#  'drb%_max_opp',
#  'blk%_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    # since we have time series data, we cannot split data up with usual cross-validation (must use historical data to predict future outcomes)
    # function will split data into season, use past seasons to predict future seasons

    # start = 2: 2 seasons min to start predicting (ex: using 2016/2017 to predict 2018)

    all_predictions = [] # list of dataframes for predictions of one season

    seasons = sorted(data["season"].unique()) # sort data by season

    for i in range(start, len(seasons), step):
        season = seasons[i] # each loop iteration is a new season
        train = data[data["season"] < season] # training data is ALL DATA BEFORE CURRENT SEASON
        test = data[data["season"] == season] # current season is tested/predicted

        model.fit(train[predictors], train["target"]) # calls model to find combinations in training data that give us most accuracy to target

        preds = model.predict(test[predictors]) # allow model to make predictions on DIFFERENT DATA than training data
        # predictions made using training data will yield unrealistically high accuracy as expected

        preds = pd.Series (preds, index=test.index) #convert predictions to Series with same index as test data

        combined = pd.concat( [test["target"], preds], axis=1) # combine predictions and real outcomes into one dataframe/table
        combined.columns = ["actual", "prediction"] # rename columns

        all_predictions.append(combined) # add predictions to list of predictions
    
    return pd.concat(all_predictions) #combine all seasons into one dataframe at the end

# %%
predictions = backtest(data, rr, predictors) # run backtest function with data, model, and predictors (metrics)

# %%
predictions
# Out:
#        actual  prediction
# 5250        1           1
# 5251        1           1
# 5252        0           0
# 5253        1           0
# 5254        0           0
# ...       ...         ...
# 17767       0           0
# 17768       1           1
# 17769       0           1
# 17770       2           0
# 17771       2           0
#
# [12522 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

predictions = predictions[predictions["actual"] != 2] # remove last game of each team (value of 2)
accuracy_score(predictions["actual"], predictions["prediction"]) # accuracy of prediction

# ***********************************************
# ACCURACY OF UNOPTIMIZED MODEL: 54.5% 
# ***********************************************
# Out:
# 0.5452289465257765

# %%
data.groupby("home").apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0]) # split data into home and away, find win percentages
# baseline model accuracy
# Out:
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %%
data
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.418605  0.412698  0.654609  ...      0.277279      0.554502
# 1      0.209302  0.253968  0.519253  ...      0.160462      0.345972
# 2      0.348837  0.349206  0.645274  ...      0.088575      0.232227
# 3      0.441860  0.333333  0.893816  ...      0.215661      0.530806
# 4      0.255814  0.222222  0.766628  ...      0.019255      0.203791
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.285714  0.693116  ...      0.182285      0.208531
# 17768  0.279070  0.222222  0.844807  ...      0.928113      1.000000
# 17769  0.465116  0.476190  0.623104  ...      0.181001      0.630332
# 17770  0.232558  0.174603  0.903151  ...      0.120668      0.459716
# 17771  0.162791  0.111111  1.000000  ...      0.263158      0.246445
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season        date    won  \
# 0          0.317647       GSW   0.451923       1.0    2016  2015-10-27  False
# 1          0.317647       CHI   0.317308       1.0    2016  2015-10-27  False
# 2          0.329412       CLE   0.298077       0.0    2016  2015-10-27   True
# 3          0.505882       NOP   0.298077       0.0    2016  2015-10-27   True
# 4          0.317647       DET   0.403846       0.0    2016  2015-10-27  False
# ...             ...       ...        ...       ...     ...         ...    ...
# 17767      0.411765       GSW   0.413462       0.0    2022  2022-06-10  False
# 17768      0.411765       BOS   0.288462       0.0    2022  2022-06-13   True
# 17769      0.352941       GSW   0.384615       1.0    2022  2022-06-13  False
# 17770      0.400000       GSW   0.375000       0.0    2022  2022-06-16  False
# 17771      0.576471       BOS   0.250000       1.0    2022  2022-06-16   True
#
#        target
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 17767       0
# 17768       1
# 17769       0
# 17770       2
# 17771       2
#
# [17772 rows x 142 columns]

# %%
data_rolling = data[list(selected_columns) + ["won", "team", "season"]] #subset of initial data
# only scaled columns + specified columns

# %%
def find_team_averages(team):
    rolling = team.rolling(10).mean() # rolling average of the previous 10 games
    # .rolling() -> pandas function to group the 10 rows together
    # .mean() -> pandas function to find the mean of the grouped rows

    return rolling

data_rolling = data_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages) 
# group by team and season to see one team's performance over time
# apply function to each group to find rolling averages

# %%
data_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  stl%_max_opp  blk%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.434884  0.373016  0.764177  ...        0.0570        0.1113
# 17768  0.320930  0.282540  0.757993  ...        0.0716        0.1171
# 17769  0.434884  0.385714  0.736639  ...        0.0591        0.1113
# 17770  0.406977  0.357143  0.754142  ...        0.0572        0.1111
# 17771  0.316279  0.269841  0.801750  ...        0.0656        0.1152
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  \
# 0               NaN           NaN           NaN           NaN        NaN
# 1               NaN           NaN           NaN           NaN        NaN
# 2               NaN           NaN           NaN           NaN        NaN
# 3               NaN           NaN           NaN           NaN        NaN
# 4               NaN           NaN           NaN           NaN        NaN
# ...             ...           ...           ...           ...        ...
# 17767      0.471908      0.170603      0.431754      0.522353   0.348077
# 17768      0.374109      0.321566      0.642654      0.564706   0.392308
# 17769      0.483229      0.174711      0.438863      0.483529   0.350000
# 17770      0.483229      0.172144      0.460190      0.472941   0.344231
# 17771      0.444025      0.308601      0.628910      0.568235   0.395192
#
#        home_opp  won  season
# 0           NaN  NaN     NaN
# 1           NaN  NaN     NaN
# 2           NaN  NaN     NaN
# 3           NaN  NaN     NaN
# 4           NaN  NaN     NaN
# ...         ...  ...     ...
# 17767       0.5  0.6  2022.0
# 17768       0.4  0.7  2022.0
# 17769       0.5  0.5  2022.0
# 17770       0.5  0.5  2022.0
# 17771       0.5  0.7  2022.0
#
# [17772 rows x 138 columns]

# %%
joblib.dump(sfs, 'feature_selector_unoptimized.pkl') # save the feature selector to a file for later use
# Out:
# ['feature_selector_unoptimized.pkl']

# %%
sfs = joblib.load('feature_selector_unoptimized.pkl') # load the feature selector from file for future use

# %%
data_rolling
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100
# 17768  0.0  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736
# 17769  0.0  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572
# 17770  0.0  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710
# 17771  0.0  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812
#
#              ft       fta       ft%  ...  stl%_max_opp  blk%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.434884  0.373016  0.764177  ...        0.0570        0.1113
# 17768  0.320930  0.282540  0.757993  ...        0.0716        0.1171
# 17769  0.434884  0.385714  0.736639  ...        0.0591        0.1113
# 17770  0.406977  0.357143  0.754142  ...        0.0572        0.1111
# 17771  0.316279  0.269841  0.801750  ...        0.0656        0.1152
#
#        tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  total_opp  \
# 0               NaN           NaN           NaN           NaN        NaN
# 1               NaN           NaN           NaN           NaN        NaN
# 2               NaN           NaN           NaN           NaN        NaN
# 3               NaN           NaN           NaN           NaN        NaN
# 4               NaN           NaN           NaN           NaN        NaN
# ...             ...           ...           ...           ...        ...
# 17767      0.471908      0.170603      0.431754      0.522353   0.348077
# 17768      0.374109      0.321566      0.642654      0.564706   0.392308
# 17769      0.483229      0.174711      0.438863      0.483529   0.350000
# 17770      0.483229      0.172144      0.460190      0.472941   0.344231
# 17771      0.444025      0.308601      0.628910      0.568235   0.395192
#
#        home_opp  won  season
# 0           NaN  NaN     NaN
# 1           NaN  NaN     NaN
# 2           NaN  NaN     NaN
# 3           NaN  NaN     NaN
# 4           NaN  NaN     NaN
# ...         ...  ...     ...
# 17767       0.5  0.6  2022.0
# 17768       0.4  0.7  2022.0
# 17769       0.5  0.5  2022.0
# 17770       0.5  0.5  2022.0
# 17771       0.5  0.7  2022.0
#
# [17772 rows x 138 columns]

# %%
rolling_cols = [f"{col} (last10)" for col in data_rolling.columns]
data_rolling.columns = rolling_cols # rename columns to show "last 10"

data = pd.concat([data, data_rolling], axis=1) # combine original data with rolling averages (will give double the columns)

# %%
data # new dataframe with rolling averages added in
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.363636  0.338235  0.366029  0.206897  0.212121  0.395487
# 1      0.0  0.431818  0.500000  0.322967  0.310345  0.378788  0.368171
# 2      0.0  0.409091  0.397059  0.373206  0.241379  0.227273  0.437055
# 3      0.0  0.500000  0.529412  0.377990  0.310345  0.393939  0.356295
# 4      0.0  0.409091  0.323529  0.435407  0.275862  0.348485  0.351544
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  stl%_max_opp (last10)  \
# 0      0.418605  0.412698  0.654609  ...                    NaN
# 1      0.209302  0.253968  0.519253  ...                    NaN
# 2      0.348837  0.349206  0.645274  ...                    NaN
# 3      0.441860  0.333333  0.893816  ...                    NaN
# 4      0.255814  0.222222  0.766628  ...                    NaN
# ...         ...       ...       ...  ...                    ...
# 17767  0.302326  0.285714  0.693116  ...                 0.0570
# 17768  0.279070  0.222222  0.844807  ...                 0.0716
# 17769  0.465116  0.476190  0.623104  ...                 0.0591
# 17770  0.232558  0.174603  0.903151  ...                 0.0572
# 17771  0.162791  0.111111  1.000000  ...                 0.0656
#
#        blk%_max_opp (last10)  tov%_max_opp (last10)  usg%_max_opp (last10)  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 17767                 0.1113               0.471908               0.170603
# 17768                 0.1171               0.374109               0.321566
# 17769                 0.1113               0.483229               0.174711
# 17770                 0.1111               0.483229               0.172144
# 17771                 0.1152               0.444025               0.308601
#
#        ortg_max_opp (last10)  drtg_max_opp (last10)  total_opp (last10)  \
# 0                        NaN                    NaN                 NaN
# 1                        NaN                    NaN                 NaN
# 2                        NaN                    NaN                 NaN
# 3                        NaN                    NaN                 NaN
# 4                        NaN                    NaN                 NaN
# ...                      ...                    ...                 ...
# 17767               0.431754               0.522353            0.348077
# 17768               0.642654               0.564706            0.392308
# 17769               0.438863               0.483529            0.350000
# 17770               0.460190               0.472941            0.344231
# 17771               0.628910               0.568235            0.395192
#
#        home_opp (last10)  won (last10)  season (last10)
# 0                    NaN           NaN              NaN
# 1                    NaN           NaN              NaN
# 2                    NaN           NaN              NaN
# 3                    NaN           NaN              NaN
# 4                    NaN           NaN              NaN
# ...                  ...           ...              ...
# 17767                0.5           0.6           2022.0
# 17768                0.4           0.7           2022.0
# 17769                0.5           0.5           2022.0
# 17770                0.5           0.5           2022.0
# 17771                0.5           0.7           2022.0
#
# [17772 rows x 280 columns]

# %%
data = data.dropna() # drops rows with NaN values
data
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  stl%_max_opp (last10)  \
# 243    0.255814  0.238095  0.708285  ...                 0.0628
# 251    0.325581  0.238095  0.927655  ...                 0.0613
# 252    0.511628  0.412698  0.827305  ...                 0.0625
# 253    0.325581  0.349206  0.593932  ...                 0.0646
# 256    0.581395  0.444444  0.879813  ...                 0.0741
# ...         ...       ...       ...  ...                    ...
# 17767  0.302326  0.285714  0.693116  ...                 0.0570
# 17768  0.279070  0.222222  0.844807  ...                 0.0716
# 17769  0.465116  0.476190  0.623104  ...                 0.0591
# 17770  0.232558  0.174603  0.903151  ...                 0.0572
# 17771  0.162791  0.111111  1.000000  ...                 0.0656
#
#        blk%_max_opp (last10)  tov%_max_opp (last10)  usg%_max_opp (last10)  \
# 243                   0.0679               0.413522               0.124134
# 251                   0.0772               0.469497               0.219641
# 252                   0.1145               0.437841               0.138126
# 253                   0.0759               0.512159               0.133633
# 256                   0.0982               0.313312               0.179974
# ...                      ...                    ...                    ...
# 17767                 0.1113               0.471908               0.170603
# 17768                 0.1171               0.374109               0.321566
# 17769                 0.1113               0.483229               0.174711
# 17770                 0.1111               0.483229               0.172144
# 17771                 0.1152               0.444025               0.308601
#
#        ortg_max_opp (last10)  drtg_max_opp (last10)  total_opp (last10)  \
# 243                 0.361611               0.449412            0.347115
# 251                 0.394787               0.531765            0.324038
# 252                 0.507109               0.360000            0.351923
# 253                 0.277251               0.388235            0.308654
# 256                 0.500000               0.471765            0.380769
# ...                      ...                    ...                 ...
# 17767               0.431754               0.522353            0.348077
# 17768               0.642654               0.564706            0.392308
# 17769               0.438863               0.483529            0.350000
# 17770               0.460190               0.472941            0.344231
# 17771               0.628910               0.568235            0.395192
#
#        home_opp (last10)  won (last10)  season (last10)
# 243                  0.4           0.8           2016.0
# 251                  0.5           1.0           2016.0
# 252                  0.6           0.4           2016.0
# 253                  0.4           0.6           2016.0
# 256                  0.5           0.4           2016.0
# ...                  ...           ...              ...
# 17767                0.5           0.6           2022.0
# 17768                0.4           0.7           2022.0
# 17769                0.5           0.5           2022.0
# 17770                0.5           0.5           2022.0
# 17771                0.5           0.7           2022.0
#
# [15882 rows x 280 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1) 
    return next_col
    # general function that takes the value of a metric and shifts it back to the last game

def add_col(data, col_name):
    return data.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name)) # lambda x -> anonymous function
    # apply shift_col function to each team group when add_col is called

data["home_next"] = add_col(data, "home")
# new column called home_next
# add_col function returns output of col_name applied to each team group
# home column values shifted back to last game 
# allows model to use home/away info for next matchup

data["team_opp_next"] = add_col(data, "team_opp")
data["date_next"] = add_col(data, "date")
# should ONLY be done for data we would know in advance (future opponent, home/away, date)
# don't use on game specific stats
# Out:
# <ipython-input-51-9687600ef7e2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["home_next"] = add_col(data, "home")
# <ipython-input-51-9687600ef7e2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["team_opp_next"] = add_col(data, "team_opp")
# <ipython-input-51-9687600ef7e2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["date_next"] = add_col(data, "date")

# %%
data
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    0.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    0.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    0.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    0.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    0.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  0.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  0.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  0.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  0.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp (last10)  \
# 243    0.255814  0.238095  0.708285  ...               0.124134
# 251    0.325581  0.238095  0.927655  ...               0.219641
# 252    0.511628  0.412698  0.827305  ...               0.138126
# 253    0.325581  0.349206  0.593932  ...               0.133633
# 256    0.581395  0.444444  0.879813  ...               0.179974
# ...         ...       ...       ...  ...                    ...
# 17767  0.302326  0.285714  0.693116  ...               0.170603
# 17768  0.279070  0.222222  0.844807  ...               0.321566
# 17769  0.465116  0.476190  0.623104  ...               0.174711
# 17770  0.232558  0.174603  0.903151  ...               0.172144
# 17771  0.162791  0.111111  1.000000  ...               0.308601
#
#        ortg_max_opp (last10)  drtg_max_opp (last10)  total_opp (last10)  \
# 243                 0.361611               0.449412            0.347115
# 251                 0.394787               0.531765            0.324038
# 252                 0.507109               0.360000            0.351923
# 253                 0.277251               0.388235            0.308654
# 256                 0.500000               0.471765            0.380769
# ...                      ...                    ...                 ...
# 17767               0.431754               0.522353            0.348077
# 17768               0.642654               0.564706            0.392308
# 17769               0.438863               0.483529            0.350000
# 17770               0.460190               0.472941            0.344231
# 17771               0.628910               0.568235            0.395192
#
#        home_opp (last10)  won (last10)  season (last10)  home_next  \
# 243                  0.4           0.8           2016.0        0.0
# 251                  0.5           1.0           2016.0        1.0
# 252                  0.6           0.4           2016.0        0.0
# 253                  0.4           0.6           2016.0        0.0
# 256                  0.5           0.4           2016.0        0.0
# ...                  ...           ...              ...        ...
# 17767                0.5           0.6           2022.0        0.0
# 17768                0.4           0.7           2022.0        0.0
# 17769                0.5           0.5           2022.0        1.0
# 17770                0.5           0.5           2022.0        NaN
# 17771                0.5           0.7           2022.0        NaN
#
#        team_opp_next   date_next
# 243              BOS  2015-11-13
# 251              BRK  2015-11-14
# 252              MIN  2015-11-15
# 253              CHI  2015-11-16
# 256              CHO  2015-11-15
# ...              ...         ...
# 17767            GSW  2022-06-13
# 17768            BOS  2022-06-16
# 17769            GSW  2022-06-16
# 17770            NaN         NaN
# 17771            NaN         NaN
#
# [15882 rows x 283 columns]

# %%
data = data.copy() # to avoid SettingWithCopyWarning

# %%
full = data.merge(
    data[rolling_cols + ["team_opp_next", "date_next", "team"]], # all prediction columns
    left_on=["team", "date_next"], # our team data
    right_on=["team_opp_next", "date_next"]) #opponent data

# merging useful prediction data (rolling data, future opponent, current team, date) into one dataframe

# %%
full
# Out:
#          mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.00  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      0.00  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      0.50  0.409091  0.455882  0.330144  0.482759  0.515152  0.437055
# 3      0.25  0.545455  0.544118  0.416268  0.413793  0.454545  0.419240
# 4      0.00  0.340909  0.558824  0.186603  0.206897  0.469697  0.203088
# ...     ...       ...       ...       ...       ...       ...       ...
# 15769  0.00  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  0.00  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  0.00  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  0.00  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  0.00  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  tov%_max_opp (last10)_y  \
# 0      0.441860  0.396825  0.730455  ...                 0.380294
# 1      0.511628  0.412698  0.827305  ...                 0.437212
# 2      0.372093  0.412698  0.568261  ...                 0.504403
# 3      0.186047  0.142857  0.883314  ...                 0.467505
# 4      0.139535  0.111111  0.854142  ...                 0.413732
# ...         ...       ...       ...  ...                      ...
# 15769  0.372093  0.365079  0.659277  ...                 0.457128
# 15770  0.255814  0.222222  0.766628  ...                 0.471908
# 15771  0.302326  0.285714  0.693116  ...                 0.431761
# 15772  0.279070  0.222222  0.844807  ...                 0.483229
# 15773  0.465116  0.476190  0.623104  ...                 0.374109
#
#        usg%_max_opp (last10)_y  ortg_max_opp (last10)_y  \
# 0                     0.273427                 0.270616
# 1                     0.124904                 0.404739
# 2                     0.153273                 0.344076
# 3                     0.276508                 0.352607
# 4                     0.156739                 0.470142
# ...                        ...                      ...
# 15769                 0.235173                 0.562085
# 15770                 0.170603                 0.431754
# 15771                 0.242875                 0.567773
# 15772                 0.174711                 0.438863
# 15773                 0.321566                 0.642654
#
#        drtg_max_opp (last10)_y  total_opp (last10)_y  home_opp (last10)_y  \
# 0                     0.478824              0.308654                  0.6
# 1                     0.408235              0.428846                  0.2
# 2                     0.384706              0.319231                  0.7
# 3                     0.482353              0.316346                  0.7
# 4                     0.391765              0.436538                  0.6
# ...                        ...                   ...                  ...
# 15769                 0.552941              0.429808                  0.4
# 15770                 0.522353              0.348077                  0.5
# 15771                 0.575294              0.394231                  0.4
# 15772                 0.483529              0.350000                  0.5
# 15773                 0.564706              0.392308                  0.4
#
#        won (last10)_y  season (last10)_y  team_opp_next_y  team_y
# 0                 0.7             2016.0              SAC     TOR
# 1                 0.3             2016.0              TOR     SAC
# 2                 0.5             2016.0              CLE     DET
# 3                 0.6             2016.0              GSW     TOR
# 4                 0.1             2016.0              DEN     NOP
# ...               ...                ...              ...     ...
# 15769             0.6             2022.0              BOS     GSW
# 15770             0.6             2022.0              GSW     BOS
# 15771             0.7             2022.0              BOS     GSW
# 15772             0.5             2022.0              GSW     BOS
# 15773             0.7             2022.0              BOS     GSW
#
# [15774 rows x 423 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        SAC             TOR    TOR             SAC  2015-11-15
# 1        TOR             SAC    SAC             TOR  2015-11-15
# 2        CLE             DET    DET             CLE  2015-11-17
# 3        GSW             TOR    TOR             GSW  2015-11-17
# 4        DEN             NOP    NOP             DEN  2015-11-17
# ...      ...             ...    ...             ...         ...
# 15769    BOS             GSW    GSW             BOS  2022-06-10
# 15770    GSW             BOS    BOS             GSW  2022-06-13
# 15771    BOS             GSW    GSW             BOS  2022-06-13
# 15772    GSW             BOS    BOS             GSW  2022-06-16
# 15773    BOS             GSW    GSW             BOS  2022-06-16
#
# [15774 rows x 5 columns]

# %%
full.columns[full.dtypes == "object"] # non-numerical columns
# Out:
# Index(['team_x', 'team_opp', 'date', 'team_opp_next_x', 'date_next',
#        'team_opp_next_y', 'team_y'],
#       dtype='object')

# %%
removed_columns
# Out:
# ['season', 'date', 'won', 'target', 'team', 'team_opp']

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)] # negate columns in removed_columns

# %%
data.to_csv('data/nba_games_rolling_averages.csv', index=False) # STORE NEW ROLLING AVG DATA FOR OPTIMAL FEATURE1q  \ SELECTOR

# %%
sfs.fit(full[selected_columns], full["target"]) # refit feature selector to new data with rolling averages
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=0.1),
#                           n_features_to_select=30)

# %%
joblib.dump(sfs, 'feature_selector_optimized_with_rolling_averages.pkl') # save the feature selector to a file for later use
# Out:
# ['feature_selector_optimized_with_rolling_averages.pkl']

# %%
predictors = list(selected_columns[sfs.get_support()]) # get the selected features from the feature selector
predictors
# Out:
# ['mp',
#  '3p%',
#  'usg%',
#  '3p_max',
#  'drb_max',
#  'ortg_max',
#  'mp_opp',
#  'ft_opp',
#  'usg%_opp',
#  'ft%_max_opp',
#  'usg%_max_opp',
#  '3p (last10)_x',
#  'fta (last10)_x',
#  'usg% (last10)_x',
#  'orb%_max (last10)_x',
#  'ftr_opp (last10)_x',
#  'usg%_opp (last10)_x',
#  '3p_max_opp (last10)_x',
#  'ast_max_opp (last10)_x',
#  'orb%_max_opp (last10)_x',
#  'won (last10)_x',
#  'home_next',
#  'orb% (last10)_y',
#  'usg% (last10)_y',
#  'pts_max (last10)_y',
#  '+/-_max (last10)_y',
#  'ts%_max (last10)_y',
#  'efg%_max (last10)_y',
#  'usg%_opp (last10)_y',
#  'ft%_max_opp (last10)_y']

# %%
predictions = backtest(full, rr, predictors) # run backtest function with new data, model, and predictors (metrics)

# %%
accuracy_score(predictions["actual"], predictions["prediction"]) # accuracy of prediction (compare actual to predictions)
# Out:
# 0.6355771830224385
